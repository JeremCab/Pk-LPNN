# %% [markdown]
# # Read results

# %%
import os
import pickle

import pandas as pd
import numpy as np

# %% [markdown]
# ## Leukemia

# %%
cwd = os.getcwd()
cwd
# Out:
# '/Users/jeremie.cabessau-paris2.fr/Desktop/MAIN/Students/2024_Nourane_Fradi/code'

# %%
results_folder = os.path.join(cwd, "results/genetic_data_LEUKEMIA")
results_folder
# Out:
# '/Users/jeremie.cabessau-paris2.fr/Desktop/MAIN/Students/2024_Nourane_Fradi/code/results/genetic_data_LEUKEMIA'

# %%
nzs = ["45", "89", "178", "356", "712"]
fts_modes = ["full", "random", "k-best", "k-best-mi", "sparse-pca", "pk-lpnn"]
models = ["knn", "lr", "nb-gaussian", "svc"]

results_d = {}

for nz in nzs:

    results_d[nz] = {}
    
    for fts_mode in fts_modes:
    
        results_d[nz][fts_mode] = {}
        
        for model in models:
            
            with open( os.path.join(results_folder, f"{nz}", f"{fts_mode}_{nz}_{model}.pkl"), "rb" ) as fh:
                
                results = pickle.load(fh)
                f1 = np.mean(results["f1"]).round(3)
                b_acc = np.mean(results["b_acc"]).round(3)
                # print("f1: ", f1, "b_acc: ", b_acc)
    
                results_d[nz][fts_mode][model] = (f1, b_acc)

# %%
results_df = {}

for nz in nzs:
    
    results_df[nz] = pd.DataFrame.from_dict(results_d[nz])

# %%
results_df["45"]
# Out:
#                        full          random          k-best       k-best-mi  \
# knn          (0.846, 0.874)  (0.655, 0.709)  (0.812, 0.871)    (0.9, 0.933)
# lr           (0.894, 0.937)  (0.711, 0.766)  (0.801, 0.862)    (0.9, 0.933)
# nb-gaussian    (0.77, 0.81)   (0.59, 0.673)  (0.814, 0.874)  (0.891, 0.926)
# svc          (0.428, 0.543)  (0.352, 0.509)   (0.26, 0.494)  (0.315, 0.526)
#
#                  sparse-pca         pk-lpnn
# knn          (0.846, 0.897)  (0.879, 0.913)
# lr           (0.885, 0.928)  (0.881, 0.916)
# nb-gaussian  (0.822, 0.876)   (0.672, 0.77)
# svc          (0.547, 0.621)  (0.244, 0.485)

# %%
results_df["89"]
# Out:
#                        full          random          k-best       k-best-mi  \
# knn          (0.846, 0.874)  (0.682, 0.731)  (0.854, 0.906)  (0.903, 0.938)
# lr           (0.894, 0.937)  (0.767, 0.836)  (0.832, 0.888)  (0.897, 0.933)
# nb-gaussian    (0.77, 0.81)  (0.671, 0.743)  (0.872, 0.918)   (0.89, 0.929)
# svc          (0.428, 0.543)  (0.362, 0.517)  (0.246, 0.487)   (0.296, 0.51)
#
#                  sparse-pca         pk-lpnn
# knn          (0.873, 0.911)  (0.886, 0.922)
# lr           (0.909, 0.942)   (0.879, 0.92)
# nb-gaussian   (0.87, 0.909)  (0.762, 0.835)
# svc          (0.525, 0.601)  (0.246, 0.487)

# %%
# Good!
results_df["178"]
# Out:
#                        full          random          k-best       k-best-mi  \
# knn          (0.846, 0.874)  (0.768, 0.804)  (0.851, 0.904)  (0.913, 0.946)
# lr           (0.894, 0.937)  (0.807, 0.858)  (0.852, 0.903)    (0.9, 0.936)
# nb-gaussian    (0.77, 0.81)  (0.705, 0.768)  (0.885, 0.927)  (0.878, 0.921)
# svc          (0.428, 0.543)   (0.379, 0.52)  (0.244, 0.485)  (0.278, 0.499)
#
#                  sparse-pca         pk-lpnn
# knn          (0.889, 0.923)  (0.913, 0.945)
# lr           (0.912, 0.945)  (0.912, 0.947)
# nb-gaussian  (0.898, 0.932)  (0.856, 0.903)
# svc          (0.449, 0.558)  (0.246, 0.487)

# %%
results_df["356"]
# Out:
#                        full          random          k-best       k-best-mi  \
# knn          (0.846, 0.874)     (0.8, 0.84)  (0.886, 0.928)    (0.92, 0.95)
# lr           (0.894, 0.937)  (0.868, 0.913)  (0.882, 0.926)  (0.912, 0.948)
# nb-gaussian    (0.77, 0.81)  (0.749, 0.807)  (0.888, 0.926)  (0.886, 0.925)
# svc          (0.428, 0.543)  (0.372, 0.525)  (0.244, 0.485)  (0.277, 0.496)
#
#                  sparse-pca         pk-lpnn
# knn          (0.896, 0.929)  (0.916, 0.944)
# lr           (0.927, 0.954)  (0.908, 0.941)
# nb-gaussian  (0.876, 0.916)   (0.884, 0.91)
# svc          (0.406, 0.516)   (0.312, 0.52)

# %%
results_df["712"]
# Out:
#                        full          random          k-best       k-best-mi  \
# knn          (0.846, 0.874)  (0.815, 0.855)  (0.901, 0.938)  (0.923, 0.952)
# lr           (0.894, 0.937)  (0.864, 0.914)    (0.9, 0.937)  (0.908, 0.945)
# nb-gaussian    (0.77, 0.81)  (0.775, 0.831)  (0.883, 0.924)   (0.901, 0.93)
# svc          (0.428, 0.543)  (0.382, 0.515)  (0.244, 0.485)  (0.324, 0.522)
#
#                  sparse-pca         pk-lpnn
# knn           (0.902, 0.93)  (0.915, 0.939)
# lr           (0.925, 0.952)  (0.911, 0.948)
# nb-gaussian  (0.891, 0.929)  (0.842, 0.877)
# svc          (0.401, 0.518)  (0.325, 0.504)

# %% [markdown]
# ## DLBCL

# %%
results_folder = os.path.join(cwd, "results/genetic_data_DLBCL")
results_folder
# Out:
# '/Users/jeremie.cabessau-paris2.fr/Desktop/MAIN/Students/2024_Nourane_Fradi/code/results/genetic_data_DLBCL'

# %%
nzs = ["68", "137", "273", "547"]
fts_modes = ["full", "random", "k-best", "k-best-mi", "sparse-pca", "pk-lpnn"]
models = ["knn", "lr", "nb-gaussian", "svc"]

results_d = {}

for nz in nzs:

    results_d[nz] = {}
    
    for fts_mode in fts_modes:
    
        results_d[nz][fts_mode] = {}
        
        for model in models:
            
            with open( os.path.join(results_folder, f"{nz}", f"{fts_mode}_{nz}_{model}.pkl"), "rb" ) as fh:
                
                results = pickle.load(fh)
                f1 = np.mean(results["f1"]).round(3)
                b_acc = np.mean(results["b_acc"]).round(3)
                # print("f1: ", f1, "b_acc: ", b_acc)
    
                results_d[nz][fts_mode][model] = (f1, b_acc)

# %%
results_df = {}

for nz in nzs:
    
    results_df[nz] = pd.DataFrame.from_dict(results_d[nz])

# %%
results_df["68"]
# Out:
#                        full          random          k-best       k-best-mi  \
# knn           (0.622, 0.65)  (0.562, 0.616)  (0.842, 0.877)  (0.779, 0.809)
# lr            (0.94, 0.971)  (0.631, 0.672)   (0.87, 0.894)  (0.728, 0.754)
# nb-gaussian  (0.486, 0.553)  (0.519, 0.582)  (0.629, 0.664)   (0.455, 0.53)
# svc           (0.466, 0.54)   (0.466, 0.54)   (0.466, 0.54)  (0.463, 0.537)
#
#                  sparse-pca         pk-lpnn
# knn          (0.519, 0.575)  (0.798, 0.856)
# lr           (0.792, 0.838)  (0.816, 0.885)
# nb-gaussian  (0.487, 0.546)  (0.488, 0.634)
# svc           (0.466, 0.54)  (0.492, 0.567)

# %%
results_df["137"]
# Out:
#                        full          random          k-best       k-best-mi  \
# knn           (0.622, 0.65)  (0.591, 0.632)  (0.829, 0.861)  (0.773, 0.825)
# lr            (0.94, 0.971)  (0.717, 0.761)  (0.877, 0.906)   (0.778, 0.81)
# nb-gaussian  (0.486, 0.553)  (0.524, 0.583)  (0.592, 0.637)    (0.5, 0.575)
# svc           (0.466, 0.54)   (0.466, 0.54)   (0.466, 0.54)   (0.505, 0.58)
#
#                  sparse-pca         pk-lpnn
# knn          (0.545, 0.605)  (0.832, 0.878)
# lr           (0.877, 0.896)  (0.856, 0.909)
# nb-gaussian  (0.503, 0.559)    (0.7, 0.762)
# svc           (0.466, 0.54)  (0.488, 0.562)

# %%
results_df["273"]
# Out:
#                        full          random          k-best       k-best-mi  \
# knn           (0.622, 0.65)   (0.629, 0.67)  (0.823, 0.856)  (0.768, 0.814)
# lr            (0.94, 0.971)  (0.822, 0.866)  (0.893, 0.923)  (0.805, 0.844)
# nb-gaussian  (0.486, 0.553)  (0.505, 0.573)  (0.593, 0.633)    (0.5, 0.575)
# svc           (0.466, 0.54)   (0.466, 0.54)   (0.466, 0.54)    (0.5, 0.575)
#
#                  sparse-pca         pk-lpnn
# knn          (0.567, 0.621)  (0.857, 0.894)
# lr           (0.916, 0.939)  (0.894, 0.944)
# nb-gaussian  (0.512, 0.579)  (0.648, 0.716)
# svc           (0.466, 0.54)   (0.485, 0.56)

# %%
results_df["547"]
# Out:
#                        full          random          k-best       k-best-mi  \
# knn           (0.622, 0.65)  (0.614, 0.652)   (0.82, 0.851)  (0.764, 0.811)
# lr            (0.94, 0.971)   (0.906, 0.94)  (0.911, 0.938)  (0.874, 0.905)
# nb-gaussian  (0.486, 0.553)  (0.523, 0.581)  (0.564, 0.612)    (0.5, 0.575)
# svc           (0.466, 0.54)   (0.466, 0.54)   (0.466, 0.54)    (0.5, 0.575)
#
#                  sparse-pca         pk-lpnn
# knn          (0.615, 0.667)   (0.79, 0.821)
# lr           (0.925, 0.952)  (0.942, 0.964)
# nb-gaussian  (0.546, 0.597)   (0.57, 0.635)
# svc           (0.466, 0.54)   (0.485, 0.56)

# %% [markdown]
# ## Prostate

# %%
results_folder = os.path.join(cwd, "results/genetic_data_Prostate")
results_folder
# Out:
# '/Users/jeremie.cabessau-paris2.fr/Desktop/MAIN/Students/2024_Nourane_Fradi/code/results/genetic_data_Prostate'

# %%
nzs = ["158", "315", "630", "1260"]
fts_modes = ["full", "random", "k-best", "k-best-mi", "sparse-pca", "pk-lpnn"]
models = ["knn", "lr", "nb-gaussian", "svc"]

results_d = {}

for nz in nzs:

    results_d[nz] = {}
    
    for fts_mode in fts_modes:
    
        results_d[nz][fts_mode] = {}
        
        for model in models:
            
            with open( os.path.join(results_folder, f"{nz}", f"{fts_mode}_{nz}_{model}.pkl"), "rb" ) as fh:
                
                results = pickle.load(fh)
                f1 = np.mean(results["f1"]).round(3)
                b_acc = np.mean(results["b_acc"]).round(3)
                # print("f1: ", f1, "b_acc: ", b_acc)
    
                results_d[nz][fts_mode][model] = (f1, b_acc)

# %%
results_df = {}

for nz in nzs:
    
    results_df[nz] = pd.DataFrame.from_dict(results_d[nz])

# %%
results_df["158"]
# Out:
#                        full          random          k-best       k-best-mi  \
# knn          (0.746, 0.777)  (0.682, 0.719)  (0.879, 0.893)  (0.852, 0.874)
# lr           (0.681, 0.734)  (0.643, 0.698)  (0.883, 0.897)  (0.872, 0.892)
# nb-gaussian  (0.352, 0.515)  (0.416, 0.554)  (0.877, 0.896)  (0.814, 0.842)
# svc            (0.323, 0.5)  (0.325, 0.501)  (0.325, 0.501)    (0.323, 0.5)
#
#                  sparse-pca         pk-lpnn
# knn          (0.642, 0.687)   (0.895, 0.91)
# lr           (0.558, 0.639)  (0.928, 0.939)
# nb-gaussian  (0.682, 0.715)  (0.778, 0.811)
# svc           (0.514, 0.61)    (0.323, 0.5)

# %%
results_df["315"]
# Out:
#                        full          random          k-best       k-best-mi  \
# knn          (0.746, 0.777)  (0.723, 0.755)  (0.861, 0.879)  (0.826, 0.853)
# lr           (0.681, 0.734)  (0.688, 0.739)  (0.894, 0.909)  (0.833, 0.858)
# nb-gaussian  (0.352, 0.515)  (0.374, 0.526)   (0.858, 0.88)  (0.759, 0.793)
# svc            (0.323, 0.5)    (0.323, 0.5)    (0.323, 0.5)    (0.323, 0.5)
#
#                  sparse-pca         pk-lpnn
# knn          (0.656, 0.699)   (0.896, 0.91)
# lr           (0.578, 0.653)  (0.903, 0.917)
# nb-gaussian   (0.65, 0.696)  (0.711, 0.753)
# svc          (0.506, 0.607)    (0.323, 0.5)

# %%
results_df["630"]
# Out:
#                        full          random          k-best       k-best-mi  \
# knn          (0.746, 0.777)  (0.728, 0.759)  (0.848, 0.868)  (0.815, 0.841)
# lr           (0.681, 0.734)   (0.693, 0.74)  (0.867, 0.888)  (0.819, 0.845)
# nb-gaussian  (0.352, 0.515)   (0.374, 0.53)  (0.804, 0.832)  (0.697, 0.742)
# svc            (0.323, 0.5)  (0.325, 0.501)  (0.324, 0.501)    (0.323, 0.5)
#
#                  sparse-pca         pk-lpnn
# knn            (0.68, 0.72)  (0.876, 0.895)
# lr           (0.606, 0.675)  (0.875, 0.894)
# nb-gaussian  (0.578, 0.649)  (0.615, 0.686)
# svc           (0.47, 0.587)    (0.323, 0.5)

# %%
results_df["1260"]
# Out:
#                        full          random          k-best       k-best-mi  \
# knn          (0.746, 0.777)  (0.735, 0.766)  (0.811, 0.834)  (0.788, 0.817)
# lr           (0.681, 0.734)  (0.682, 0.734)   (0.847, 0.87)  (0.802, 0.829)
# nb-gaussian  (0.352, 0.515)  (0.363, 0.522)   (0.724, 0.76)  (0.616, 0.682)
# svc            (0.323, 0.5)    (0.323, 0.5)    (0.323, 0.5)    (0.323, 0.5)
#
#                  sparse-pca         pk-lpnn
# knn          (0.697, 0.733)   (0.85, 0.873)
# lr            (0.64, 0.697)  (0.842, 0.864)
# nb-gaussian  (0.509, 0.609)    (0.492, 0.6)
# svc          (0.421, 0.558)    (0.323, 0.5)

# %% [markdown]
# **Remarks**
#
# - For sparse-pca, the computation time increases with the number of selected features.
# - For Pk-LPNN, this is not the case: computation time independent from nb of selected features.
# - Pk-LPNN seems more robust: constant solid results across datasets, as opposed to sparse-pca (good and bad).
# - Pk-LPNN beats k-best in some cases.
# - **For the Prostate dataset, Pk-LPNN is the best method!**
# - For other datasets, no clear pattern.
# - Our approach open the research avenue for using compressive sampling methods for feature selection.

# %% [markdown]
# **Questions**
# - Diminuer alpha pour sparse-pca ?
# - Ajouter un dataset synthétique ?
# - Ajouter un dataset multiclasse binarisé ?
# - Ajouter $N_z$ à 15% ?
